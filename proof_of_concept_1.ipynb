# %%
import pandas as pd
import os
from yaml import safe_load, dump
from modules import delete_random_values, write_csv, standardise_cell_values, fill_gaps, csvsample_to_pandas, find_csv_urls, get_mapping_dicts

# %%
test_yam_path = os.path.join(os.getcwd(), "substitutions", "samp_filler.yaml")
csv_path = os.path.join(os.getcwd(), "data", "indicator_9-1-1.csv")
dict_of_nonstandard_standard_path = (os.path.join(os.getcwd(),
                                                  "substitutions",
                                                  "test_dict_of_nonstandard_standard.yaml"))
cwd = os.getcwd()
data_path = os.path.join(cwd, 'data')
out_path = os.path.join(cwd, 'out')
gap_filler_yam_path = (os.path.join
                       ("substitutions",
                        "gap_filler.yaml"))
header_mapping_yam_path = (os.path.join
                           ("substitutions",
                            "header_mapping.yaml"))

def proof_of_concept(csv_path,
                     ns=dict_of_nonstandard_standard_path, 
                     path=test_yam_path,
                     out_path=out_path,
                     file_name="test_df.csv"):
    # Creating a sample df. This is in place of csvs_to_pandas
    samp_df = csvsample_to_pandas(path_to_file=csv_path, pct=1)
    # Testing get_mapping_dicts func. Creating filler dictioary
    samp_filler_dict = get_mapping_dicts(path)
    # Creating dictionary to map non-standard terms with standard ones. 
    nonstandard_standard = get_mapping_dicts(ns)
    # Creating gaps in the data (this will not be used in production)
    holey_df = delete_random_values(samp_df)
    # Testing that the filler dict works
    refilled_df = holey_df.fillna(value=samp_filler_dict)
    # Testing that standardise dict dills gaps as expected
    samp_df = standardise_cell_values(refilled_df, nonstandard_standard)
    #Writing the df to csv locally. 
    was_written = write_csv(samp_df, out_path, 'sample.csv')
    return samp_df, was_written

poc_df, was_written = proof_of_concept(csv_path, path=test_yam_path)

# %%
poc_df
# Out:
#            Year       Country          Local Authority      Road category  \
# 0   9 years ago  Englandshire                  Fenland  yellow brick road
# 1   9 years ago  Englandshire               St. Helens  yellow brick road
# 2   9 years ago  Englandshire                 Thurrock    Highway to hell
# 3   9 years ago  Englandshire                      NaN    Highway to hell
# 4   9 years ago  Englandshire          Suffolk Coastal             A-road
# 5   9 years ago  Englandshire                 Cornwall             B-road
# 6   9 years ago  Englandshire                Bassetlaw             B-road
# 7   9 years ago   whole world                   Bolton  yellow brick road
# 8       forever  Englandshire  North East Lincolnshire  Unclassified road
# 9   9 years ago   whole world                      NaN  Unclassified road
# 10  9 years ago  Englandshire    South Gloucestershire  Unclassified road
# 11  9 years ago  Englandshire   Windsor and Maidenhead  Unclassified road
# 12      forever  Englandshire                High Peak  Unclassified road
# 13  9 years ago  Englandshire                    Lewes  Unclassified road
# 14  9 years ago  Englandshire               Tewkesbury  Unclassified road
# 15  9 years ago  Englandshire                 Rushmoor  Unclassified road
# 16  9 years ago  Englandshire                   Boston  yellow brick road
# 17  9 years ago         Wales            Pembrokeshire  yellow brick road
# 18  9 years ago      Scotland                 Highland  Unclassified road
#
#             Observation status Unit multiplier  Unit measure  \
# 0                Uuunm-defined     PunkPundits  pashentaage!
# 1   observing the unobservable     PunkPundits  pashentaage!
# 2                Uuunm-defined        infinity  pashentaage!
# 3   observing the unobservable     PunkPundits  pashentaage!
# 4                Uuunm-defined     PunkPundits  pashentaage!
# 5                Uuunm-defined        infinity  pashentaage!
# 6                Uuunm-defined     PunkPundits  pashentaage!
# 7                Uuunm-defined     PunkPundits  pashentaage!
# 8   observing the unobservable     PunkPundits  pashentaage!
# 9                Uuunm-defined     PunkPundits  pashentaage!
# 10               Uuunm-defined     PunkPundits  pashentaage!
# 11               Uuunm-defined     PunkPundits  pashentaage!
# 12               Uuunm-defined     PunkPundits  pashentaage!
# 13               Uuunm-defined     PunkPundits  pashentaage!
# 14               Uuunm-defined     PunkPundits  pashentaage!
# 15               Uuunm-defined     PunkPundits  pashentaage!
# 16               Uuunm-defined     PunkPundits  pashentaage!
# 17               Uuunm-defined     PunkPundits  pashentaage!
# 18               Uuunm-defined     PunkPundits  pashentaage!
#
#              GeoCode       Value
# 0          E07000010   99.859644
# 1          E08000013  100.000000
# 2          E06000034   35.756875
# 3          E06000040   68.726677
# 4          E07000205   53.050175
# 5         fourty two   66.892208
# 6   Here be treasure   53.615251
# 7          E08000001   59.684764
# 8          E06000012   99.154820
# 9          E06000020   99.898668
# 10         E06000025   99.947351
# 11         E06000040   98.857741
# 12         E07000037   99.432577
# 13         E07000063   96.684275
# 14         E07000083         NaN
# 15         E07000092         NaN
# 16        fourty two   99.138802
# 17         W06000009   99.320000
# 18         S12000017   96.424365

# %%
was_written
# Out:
# True
